# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.font_manager as fm
import matplotlib
import pickle
import timeit
import math
import os
import json
# import seaborn as sns
# %matplotlib inline
import datetime
from os import listdir
from os.path import isfile, join
import winsound

# %%
df4 = pd.read_csv('./complete dfs/bus 1/bus 4 complete.csv', low_memory= False)
df1 = pd.read_csv('./complete dfs/bus 1/bus 1 complete.csv', low_memory= False)

# %%
df1['Route'] = 1
df4['Route'] = 4

# %%
df = pd.concat([df1,df4])

# %%
dfs = []
for file in  os.listdir("./complete dfs/cleaned and merged/"):
    df = pd.read_csv('./complete dfs/cleaned and merged/'+file, low_memory= False)
    df = df.dropna()
    df['Route'] = file[:3]
    dfs += [df]
all = pd.concat(dfs)

# %%
dfs[0].head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  VehicleJourneyID   TimeFrame  StopID  \
# 1           1             1            4603.0  2013-01-02     319
# 2           2             2            4603.0  2013-01-02     371
# 4           4             4            4603.0  2013-01-02     383
# 7           7             7            4603.0  2013-01-02     389
# 8           8             8            4603.0  2013-01-02     391
#
#       Timestamp  AtStop  Instance  Direction  TimeToNextStop  Hour  Day  \
# 1  1.357111e+15     1.0         2          1            93.0     7    3
# 2  1.357110e+15     0.0         2          1            20.0     7    3
# 4  1.357110e+15     1.0         2          1            40.0     7    3
# 7  1.357110e+15     0.0         2          1            41.0     7    3
# 8  1.357110e+15     0.0         2          1            49.0     7    3
#
#           Avg        Summary  Temp  Rain  Wind_Speed Route
# 1  156.974359  Mostly Cloudy   9.0   0.0        31.0   001
# ...

# %%
all.to_csv("./complete dfs/complete compile/hunormus.csv")

# %%
Freq = 2500 
Dur = 1000 
winsound.Beep(Freq,Dur)

# %%
Freq = 2500 
Dur = 1000 
winsound.Beep(Freq,Dur)

# %%
all.shape
# Out:
# (11883859, 18)

# %%
all.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  VehicleJourneyID   TimeFrame  StopID  \
# 1           1             1            4603.0  2013-01-02     319
# 2           2             2            4603.0  2013-01-02     371
# 4           4             4            4603.0  2013-01-02     383
# 7           7             7            4603.0  2013-01-02     389
# 8           8             8            4603.0  2013-01-02     391
#
#       Timestamp  AtStop  Instance  Direction  TimeToNextStop  Hour  Day  \
# 1  1.357111e+15     1.0         2          1            93.0     7    3
# 2  1.357110e+15     0.0         2          1            20.0     7    3
# 4  1.357110e+15     1.0         2          1            40.0     7    3
# 7  1.357110e+15     0.0         2          1            41.0     7    3
# 8  1.357110e+15     0.0         2          1            49.0     7    3
#
#           Avg        Summary  Temp  Rain  Wind_Speed Route
# 1  156.974359  Mostly Cloudy   9.0   0.0        31.0   001
# ...

# %%
twenty = all.sample(frac=0.2)

# %%
twenty.head()
# Out:
#         Unnamed: 0  Unnamed: 0.1  VehicleJourneyID   TimeFrame  StopID  \
# 338576       15893         15893            6383.0  2012-11-29    7353
# 178592       69003         69003            6918.0  2013-01-08    1016
# 106456      106456        106456            6600.0  2013-01-18     790
# 72782        10764         10764            3481.0  2013-01-14    7401
# 68160        68160         68160            2224.0  2012-11-27    1730
#
#            Timestamp  AtStop  Instance  Direction  TimeToNextStop  Hour  Day  \
# 338576  1.354179e+15     0.0         1          0           120.0     8    4
# 178592  1.357631e+15     1.0         1          0            39.0     7    2
# 106456  1.358514e+15     1.0         1          1           101.0    12    5
# 72782   1.358156e+15     1.0         1          0           205.0     9    1
# 68160   1.354028e+15     0.0         1          1            20.0    14    2
#
#                Avg           Summary  Temp  Rain  Wind_Speed Route
# ...

# %%
twenty.to_csv("./complete dfs/complete compile/twenty.csv")
